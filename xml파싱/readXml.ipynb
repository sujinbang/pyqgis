# %% [markdown]
# ### 구분자 Unique

# %%
import xml.etree.ElementTree as ET

tree = ET.parse('layer.xml')
root = tree.getroot()

print(root.tag)
print(root.attrib)
list = []
for child in root:
    child.tag.split('_')[0]
    list.append(child.tag.split('_')[0])

list = set(list)
print(list)
# Out:
# {'ER45', 'A4', 'EC09', 'A2', 'ER40', 'ER30', 'ER32', 'ER31', 'B2', 'C3', 'ER49', 'DE', 'ER42', 'ER46', 'ER43', 'EC01', 'BE', 'B3', 'A1', 'C4', 'C5', 'AE', 'ER16', 'ER21', 'B1', 'EC08', 'ER17', 'ER36', 'A5', 'A3', 'ER47', 'ER41', 'C2', 'ER44', 'ER20'}

# %% [markdown]
# ### XML element에 div 속성 추가

# %%
import xml.etree.ElementTree as ET

tree = ET.parse('layer.xml')
root = tree.getroot()

my_keywords1 = ['A1', 'A2', 'B1', 'B2' ,'C1', 'C2']
my_keywords2 = ['AE', 'BE', 'DE']
my_keywords3 = ['EC01', 'ER16']

for element in root.iter():
    if 'div' in element.attrib:
        print(f"  (스킵) '{element.tag}' 엘리먼트는 이미 'div' 속성이 있습니다.")
        continue # 다음 엘리먼트로 바로 이동

    for keyword in my_keywords1:
        if keyword in element.tag: 
            element.set('div', 'ngii') # 'div' 속성을 'ngii' 값으로 추가 또는 업데이트
            # print(f"'{element.tag}' 태그에 div='ngii' 속성을 추가했습니다.")

    # 'div' 속성이 이미 설정되었다면, 다음 리스트(my_keywords2, my_keywords3) 검사를 건너뜀
    if 'div' in element.attrib:
        continue

    for keyword in my_keywords2:
        if keyword in element.tag: 
            element.set('div', 'ex') # 'div' 속성을 'ex' 값으로 추가 또는 업데이트
            # print(f"'{element.tag}' 태그에 div='ex' 속성을 추가했습니다.")
    
    if 'div' in element.attrib:
        continue
    
    for keyword in my_keywords3:
        if keyword in element.tag: 
            element.set('div', 'road') # 'div' 속성을 'road' 값으로 추가 또는 업데이트
            # print(f"'{element.tag}' 태그에 div='road' 속성을 추가했습니다.")

print("\n--- 속성 추가 후 XML 엘리먼트 ---")

for element in root.iter():
    print(f"태그: {element.tag}, 속성: {element.attrib}")

# 4. 변경된 XML 내용을 새 파일로 저장
# 'output.xml'이라는 새 파일에 변경된 내용을 저장합니다.
# encoding='UTF-8'은 한글이 깨지지 않도록 하며, xml_declaration=True는 XML 선언을 추가합니다.
tree.write(r'C:\sjbang\공간정보산업진흥원\code\output.xml', encoding='UTF-8', xml_declaration=True)
print("\n변경된 XML 내용이 'output.xml' 파일로 저장되었습니다.")
# Out:
# --- 속성 추가 후 XML 엘리먼트 ---
# 태그: root, 속성: {}
# 태그: A1_NODE_001, 속성: {'name': '주행경로노드', 'div': 'ex', 'year': '2025'}
# 태그: A2_LINK_002, 속성: {'name': '주행경로링크', 'div': 'ngii', 'year': '2025'}
# 태그: A3_DRIVEWAYSECTION_003, 속성: {'name': '차도구간(교량)', 'div': 'ngii', 'year': '2024'}
# 태그: A3_DRIVEWAYSECTION_004, 속성: {'name': '차도구간(터널)', 'div': 'ngii'}
# 태그: A3_DRIVEWAYSECTION_005, 속성: {'name': '차도구간(지하차도)', 'div': 'ngii'}
# 태그: A3_DRIVEWAYSECTION_006, 속성: {'name': '차도구간(고가차도)', 'div': 'ngii'}
# 태그: A3_DRIVEWAYSECTION_007, 속성: {'name': '차도구간(IC)', 'div': 'ngii'}
# 태그: A3_DRIVEWAYSECTION_008, 속성: {'name': '차도구간(JC)', 'div': 'ngii'}
# 태그: A4_SUBSIDIARYSECTION_009, 속성: {'name': '부속구간(휴게소)', 'div': 'ngii'}
# 태그: A4_SUBSIDIARYSECTION_010, 속성: {'name': '부속구간(졸음쉼터)', 'div': 'ngii'}
# 태그: A4_SUBSIDIARYSECTION_011, 속성: {'name': '부속구간(버스정류장)', 'div': 'ngii'}
# 태그: A4_SUBSIDIARYSECTION_012, 속성: {'name': '부속구간(비상정차대)', 'div': 'ngii'}
# 태그: A4_SUBSIDIARYSECTION_013, 속성: {'name': '부속구간(POP)', 'div': 'ngii'}
# 태그: A4_SUBSIDIARYSECTION_014, 속성: {'name': '부속구간(긴급제동시설)', 'div': 'ngii'}
# 태그: A5_PARKINGLOT_015, 속성: {'name': '주차면', 'div': 'ngii'}
# 태그: AE_SLOPE_016, 속성: {'name': '종단경사', 'div': 'ex'}
# 태그: B1_SAFETYSIGN_017, 속성: {'name': '교통안전표지', 'div': 'ngii'}
# 태그: B2_SURFACELINEMARK_018, 속성: {'name': '노면선표시', 'div': 'ngii'}
# 태그: B3_SURFACEMARK_019, 속성: {'name': '노면안내표시'}
# 태그: BE_ROADSIGN_020, 속성: {'name': '도로안내표지', 'div': 'ex'}
# 태그: BE_VMS_021, 속성: {'name': '도로전광표지(VMS)', 'div': 'ex'}
# 태그: C2_KILOPOST_022, 속성: {'name': '이정(거리표)', 'div': 'ngii'}
# 태그: C2_KILOPOST_023, 속성: {'name': '이정(갓길이정)', 'div': 'ngii'}
# 태그: C3_VEHICLEPROTECTIONSAFETY_024, 속성: {'name': '차량방호안전시설(중앙분리대)'}
# 태그: C3_VEHICLEPROTECTIONSAFETY_025, 속성: {'name': '차량방호안전시설(방호울타리)'}
# 태그: C3_VEHICLEPROTECTIONSAFETY_026, 속성: {'name': '차량방호안전시설(충격흡수시설)'}
# 태그: C4_SPEEDBUMP_027, 속성: {'name': '과속방지턱'}
# 태그: C5_HEIGHTBARRIER_028, 속성: {'name': '높이장애물'}
# 태그: C5_HEIGHTBARRIER_029, 속성: {'name': '차로신호제어기(LCS)'}
# 태그: DE_FACILDOT_030, 속성: {'name': '제설시설', 'div': 'ex'}
# 태그: DE_INCLINE_031, 속성: {'name': '사면(도로절개면)', 'div': 'ex'}
# 태그: DE_INCLINE_032, 속성: {'name': '사면(도로성토면)', 'div': 'ex'}
# 태그: DE_FENCE_033, 속성: {'name': '벽/울타리(석축)', 'div': 'ex'}
# 태그: DE_FENCE_034, 속성: {'name': '벽/울타리(낙석방지시설)', 'div': 'ex'}
# 태그: DE_FENCE_035, 속성: {'name': '벽/울타리(방음시설)', 'div': 'ex'}
# 태그: DE_FENCE_036, 속성: {'name': '벽/울타리(옹벽)', 'div': 'ex'}
# 태그: DE_CCTV_037, 속성: {'name': 'CCTV', 'div': 'ex'}
# 태그: DE_LIGHT_038, 속성: {'name': '가로등', 'div': 'ex'}
# 태그: DE_TOLLGATE_039, 속성: {'name': '요금소', 'div': 'ex'}
# 태그: DE_VDS_040, 속성: {'name': '차량검지기(VDS)', 'div': 'ex'}
# 태그: DE_CULVERT_041, 속성: {'name': '통로박스', 'div': 'ex'}
# 태그: DE_ROAD_042, 속성: {'name': '단위 도로면', 'div': 'ex'}
# 태그: DE_ROADPAVEMENT_043, 속성: {'name': '단위 포장면', 'div': 'ex'}
# 태그: DE_DSRC_044, 속성: {'name': 'DSRC', 'div': 'ex'}
# 태그: DE_SOS_045, 속성: {'name': '긴급전화', 'div': 'ex'}
# 태그: EC01_A0020000_046, 속성: {'name': '도로대장 총괄', 'div': 'road'}
# 태그: ER16_A9990001_047, 속성: {'name': '도로중심선교점', 'div': 'road'}
# 태그: EC08_A0080000_048, 속성: {'name': '교차시설'}
# 태그: ER17_A9990002_049, 속성: {'name': '오르막차로'}
# 태그: ER20_C0076117_050, 속성: {'name': '측구'}
# 태그: ER21_C9070001_051, 속성: {'name': '배수암거/배수관'}
# 태그: ER30_C9070001_052, 속성: {'name': '가로수'}
# 태그: ER31_C0246120_053, 속성: {'name': '지하매설물'}
# 태그: ER32_C0246341_054, 속성: {'name': '공동구'}
# 태그: ER36_C9530009_055, 속성: {'name': '생태통로'}
# 태그: ER40_A999011_056, 속성: {'name': '실연장'}
# 태그: ER41_A9990007_057, 속성: {'name': '도로구역'}
# 태그: ER42_A9990008_058, 속성: {'name': '유료도로'}
# 태그: ER43_A9990009_059, 속성: {'name': '우회도로'}
# 태그: ER44_A9990010_060, 속성: {'name': '접도구역'}
# 태그: ER45_A9990004_061, 속성: {'name': '도로점용(점)'}
# 태그: ER46_A9990005_062, 속성: {'name': '도로점용(선)'}
# 태그: ER47_A9990006_063, 속성: {'name': '도로점용(면)'}
# 태그: EC09_A0010000_064, 속성: {'name': '차도부경계'}
# 태그: ER49_A9990013_065, 속성: {'name': '측점'}
#
# 변경된 XML 내용이 'output.xml' 파일로 저장되었습니다.

# %% [markdown]
# ### XML element에 year 속성 추가

# %%
import xml.etree.ElementTree as ET

tree = ET.parse(r'C:\sjbang\공간정보산업진흥원\code\layer.xml')
root = tree.getroot()

year_2025 = ['A1_NODE_001',
            'A2_LINK_002',
            'A3_DRIVEWAYSECTION_008',
            'A4_SUBSIDIARYSECTION_009',
            'A4_SUBSIDIARYSECTION_013',
            'A5_PARKINGLOT_015',
            'B2_SURFACELINEMARK_018',
            'B3_SURFACEMARK_019',
            'C2_KILOPOST_023',
            'C5_HEIGHTBARRIER_028',
            'CE_LCS_029',
            'DE_CCTV_037',
            'DE_VDS_040',
            'DE_ROAD_042',
            'DE_ROADPAVEMENT_043',
            'DE_DSRC_044',
            'DE_SOS_045']

for element in root.iter():
    # 1. 이미 'year' 속성이 있다면 스킵
    if 'year' in element.attrib:
        print(f"  (스킵) '{element.tag}' 엘리먼트는 이미 'year' 속성이 있습니다. (현재: {element.get('year')})")
        continue

    # 2. 'year_2025' 리스트의 키워드에 해당하는지 확인
    found_2025_keyword = False # 2025년 키워드를 찾았는지 여부를 나타내는 플래그
    for keyword in year_2025:
        if keyword in element.tag:
            element.set('year', '2025')
            print(f"  '{element.tag}' 태그에 '{keyword}' 포함 -> year='2025' 추가")
            found_2025_keyword = True
            break # 해당 엘리먼트에 2025년을 부여했으니, 더 이상 이 루프를 돌 필요 없음

    # 3. 2025년 키워드를 찾지 못했다면 '2024'로 설정
    if not found_2025_keyword:
        element.set('year', '2024')
        print(f"  '{element.tag}' 태그에 2025년 키워드 없음 -> year='2024' 추가")


print("\n--- 속성 추가 후 XML 엘리먼트 ---")

for element in root.iter():
    print(f"태그: {element.tag}, 속성: {element.attrib}")

# 4. 변경된 XML 내용을 새 파일로 저장
# 'output.xml'이라는 새 파일에 변경된 내용을 저장합니다.
# encoding='UTF-8'은 한글이 깨지지 않도록 하며, xml_declaration=True는 XML 선언을 추가합니다.
tree.write(r'C:\sjbang\공간정보산업진흥원\code\output.xml', encoding='UTF-8', xml_declaration=True)
print("\n변경된 XML 내용이 'output.xml' 파일로 저장되었습니다.")
# Out:
#   'root' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   (스킵) 'A1_NODE_001' 엘리먼트는 이미 'year' 속성이 있습니다. (현재: 2025)
#   (스킵) 'A2_LINK_002' 엘리먼트는 이미 'year' 속성이 있습니다. (현재: 2025)
#   (스킵) 'A3_DRIVEWAYSECTION_003' 엘리먼트는 이미 'year' 속성이 있습니다. (현재: 2024)
#   'A3_DRIVEWAYSECTION_004' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'A3_DRIVEWAYSECTION_005' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'A3_DRIVEWAYSECTION_006' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'A3_DRIVEWAYSECTION_007' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'A3_DRIVEWAYSECTION_008' 태그에 'A3_DRIVEWAYSECTION_008' 포함 -> year='2025' 추가
#   'A4_SUBSIDIARYSECTION_009' 태그에 'A4_SUBSIDIARYSECTION_009' 포함 -> year='2025' 추가
#   'A4_SUBSIDIARYSECTION_010' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'A4_SUBSIDIARYSECTION_011' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'A4_SUBSIDIARYSECTION_012' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'A4_SUBSIDIARYSECTION_013' 태그에 'A4_SUBSIDIARYSECTION_013' 포함 -> year='2025' 추가
#   'A4_SUBSIDIARYSECTION_014' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'A5_PARKINGLOT_015' 태그에 'A5_PARKINGLOT_015' 포함 -> year='2025' 추가
#   'AE_SLOPE_016' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'B1_SAFETYSIGN_017' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'B2_SURFACELINEMARK_018' 태그에 'B2_SURFACELINEMARK_018' 포함 -> year='2025' 추가
#   'B3_SURFACEMARK_019' 태그에 'B3_SURFACEMARK_019' 포함 -> year='2025' 추가
#   'BE_ROADSIGN_020' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'BE_VMS_021' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'C2_KILOPOST_022' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'C2_KILOPOST_023' 태그에 'C2_KILOPOST_023' 포함 -> year='2025' 추가
#   'C3_VEHICLEPROTECTIONSAFETY_024' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'C3_VEHICLEPROTECTIONSAFETY_025' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'C3_VEHICLEPROTECTIONSAFETY_026' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'C4_SPEEDBUMP_027' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'C5_HEIGHTBARRIER_028' 태그에 'C5_HEIGHTBARRIER_028' 포함 -> year='2025' 추가
#   'C5_HEIGHTBARRIER_029' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'DE_FACILDOT_030' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'DE_INCLINE_031' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'DE_INCLINE_032' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'DE_FENCE_033' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'DE_FENCE_034' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'DE_FENCE_035' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'DE_FENCE_036' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'DE_CCTV_037' 태그에 'DE_CCTV_037' 포함 -> year='2025' 추가
#   'DE_LIGHT_038' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'DE_TOLLGATE_039' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'DE_VDS_040' 태그에 'DE_VDS_040' 포함 -> year='2025' 추가
#   'DE_CULVERT_041' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'DE_ROAD_042' 태그에 'DE_ROAD_042' 포함 -> year='2025' 추가
#   'DE_ROADPAVEMENT_043' 태그에 'DE_ROADPAVEMENT_043' 포함 -> year='2025' 추가
#   'DE_DSRC_044' 태그에 'DE_DSRC_044' 포함 -> year='2025' 추가
#   'DE_SOS_045' 태그에 'DE_SOS_045' 포함 -> year='2025' 추가
#   'EC01_A0020000_046' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER16_A9990001_047' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'EC08_A0080000_048' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER17_A9990002_049' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER20_C0076117_050' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER21_C9070001_051' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER30_C9070001_052' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER31_C0246120_053' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER32_C0246341_054' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER36_C9530009_055' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER40_A999011_056' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER41_A9990007_057' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER42_A9990008_058' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER43_A9990009_059' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER44_A9990010_060' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER45_A9990004_061' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER46_A9990005_062' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER47_A9990006_063' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'EC09_A0010000_064' 태그에 2025년 키워드 없음 -> year='2024' 추가
#   'ER49_A9990013_065' 태그에 2025년 키워드 없음 -> year='2024' 추가
#
# --- 속성 추가 후 XML 엘리먼트 ---
# 태그: root, 속성: {'year': '2024'}
# 태그: A1_NODE_001, 속성: {'name': '주행경로노드', 'year': '2025'}
# 태그: A2_LINK_002, 속성: {'name': '주행경로링크', 'div': 'ngii', 'year': '2025'}
# 태그: A3_DRIVEWAYSECTION_003, 속성: {'name': '차도구간(교량)', 'div': 'ngii', 'year': '2024'}
# 태그: A3_DRIVEWAYSECTION_004, 속성: {'name': '차도구간(터널)', 'div': 'ngii', 'year': '2024'}
# 태그: A3_DRIVEWAYSECTION_005, 속성: {'name': '차도구간(지하차도)', 'div': 'ngii', 'year': '2024'}
# 태그: A3_DRIVEWAYSECTION_006, 속성: {'name': '차도구간(고가차도)', 'div': 'ngii', 'year': '2024'}
# 태그: A3_DRIVEWAYSECTION_007, 속성: {'name': '차도구간(IC)', 'div': 'ngii', 'year': '2024'}
# 태그: A3_DRIVEWAYSECTION_008, 속성: {'name': '차도구간(JC)', 'div': 'ngii', 'year': '2025'}
# 태그: A4_SUBSIDIARYSECTION_009, 속성: {'name': '부속구간(휴게소)', 'div': 'ngii', 'year': '2025'}
# 태그: A4_SUBSIDIARYSECTION_010, 속성: {'name': '부속구간(졸음쉼터)', 'div': 'ngii', 'year': '2024'}
# 태그: A4_SUBSIDIARYSECTION_011, 속성: {'name': '부속구간(버스정류장)', 'div': 'ngii', 'year': '2024'}
# 태그: A4_SUBSIDIARYSECTION_012, 속성: {'name': '부속구간(비상정차대)', 'div': 'ngii', 'year': '2024'}
# 태그: A4_SUBSIDIARYSECTION_013, 속성: {'name': '부속구간(POP)', 'div': 'ngii', 'year': '2025'}
# 태그: A4_SUBSIDIARYSECTION_014, 속성: {'name': '부속구간(긴급제동시설)', 'div': 'ngii', 'year': '2024'}
# 태그: A5_PARKINGLOT_015, 속성: {'name': '주차면', 'div': 'ngii', 'year': '2025'}
# 태그: AE_SLOPE_016, 속성: {'name': '종단경사', 'div': 'ex', 'year': '2024'}
# 태그: B1_SAFETYSIGN_017, 속성: {'name': '교통안전표지', 'year': '2024'}
# 태그: B2_SURFACELINEMARK_018, 속성: {'name': '노면선표시', 'year': '2025'}
# 태그: B3_SURFACEMARK_019, 속성: {'name': '노면안내표시', 'year': '2025'}
# 태그: BE_ROADSIGN_020, 속성: {'name': '도로안내표지', 'year': '2024'}
# 태그: BE_VMS_021, 속성: {'name': '도로전광표지(VMS)', 'year': '2024'}
# 태그: C2_KILOPOST_022, 속성: {'name': '이정(거리표)', 'year': '2024'}
# 태그: C2_KILOPOST_023, 속성: {'name': '이정(갓길이정)', 'year': '2025'}
# 태그: C3_VEHICLEPROTECTIONSAFETY_024, 속성: {'name': '차량방호안전시설(중앙분리대)', 'year': '2024'}
# 태그: C3_VEHICLEPROTECTIONSAFETY_025, 속성: {'name': '차량방호안전시설(방호울타리)', 'year': '2024'}
# 태그: C3_VEHICLEPROTECTIONSAFETY_026, 속성: {'name': '차량방호안전시설(충격흡수시설)', 'year': '2024'}
# 태그: C4_SPEEDBUMP_027, 속성: {'name': '과속방지턱', 'year': '2024'}
# 태그: C5_HEIGHTBARRIER_028, 속성: {'name': '높이장애물', 'year': '2025'}
# 태그: C5_HEIGHTBARRIER_029, 속성: {'name': '차로신호제어기(LCS)', 'year': '2024'}
# 태그: DE_FACILDOT_030, 속성: {'name': '제설시설', 'year': '2024'}
# 태그: DE_INCLINE_031, 속성: {'name': '사면(도로절개면)', 'year': '2024'}
# 태그: DE_INCLINE_032, 속성: {'name': '사면(도로성토면)', 'year': '2024'}
# 태그: DE_FENCE_033, 속성: {'name': '벽/울타리(석축)', 'year': '2024'}
# 태그: DE_FENCE_034, 속성: {'name': '벽/울타리(낙석방지시설)', 'year': '2024'}
# 태그: DE_FENCE_035, 속성: {'name': '벽/울타리(방음시설)', 'year': '2024'}
# 태그: DE_FENCE_036, 속성: {'name': '벽/울타리(옹벽)', 'year': '2024'}
# 태그: DE_CCTV_037, 속성: {'name': 'CCTV', 'year': '2025'}
# 태그: DE_LIGHT_038, 속성: {'name': '가로등', 'year': '2024'}
# 태그: DE_TOLLGATE_039, 속성: {'name': '요금소', 'year': '2024'}
# 태그: DE_VDS_040, 속성: {'name': '차량검지기(VDS)', 'year': '2025'}
# 태그: DE_CULVERT_041, 속성: {'name': '통로박스', 'year': '2024'}
# 태그: DE_ROAD_042, 속성: {'name': '단위 도로면', 'year': '2025'}
# 태그: DE_ROADPAVEMENT_043, 속성: {'name': '단위 포장면', 'year': '2025'}
# 태그: DE_DSRC_044, 속성: {'name': 'DSRC', 'year': '2025'}
# 태그: DE_SOS_045, 속성: {'name': '긴급전화', 'year': '2025'}
# 태그: EC01_A0020000_046, 속성: {'name': '도로대장 총괄', 'year': '2024'}
# 태그: ER16_A9990001_047, 속성: {'name': '도로중심선교점', 'year': '2024'}
# 태그: EC08_A0080000_048, 속성: {'name': '교차시설', 'year': '2024'}
# 태그: ER17_A9990002_049, 속성: {'name': '오르막차로', 'year': '2024'}
# 태그: ER20_C0076117_050, 속성: {'name': '측구', 'year': '2024'}
# 태그: ER21_C9070001_051, 속성: {'name': '배수암거/배수관', 'year': '2024'}
# 태그: ER30_C9070001_052, 속성: {'name': '가로수', 'year': '2024'}
# 태그: ER31_C0246120_053, 속성: {'name': '지하매설물', 'year': '2024'}
# 태그: ER32_C0246341_054, 속성: {'name': '공동구', 'year': '2024'}
# 태그: ER36_C9530009_055, 속성: {'name': '생태통로', 'year': '2024'}
# 태그: ER40_A999011_056, 속성: {'name': '실연장', 'year': '2024'}
# 태그: ER41_A9990007_057, 속성: {'name': '도로구역', 'year': '2024'}
# 태그: ER42_A9990008_058, 속성: {'name': '유료도로', 'year': '2024'}
# 태그: ER43_A9990009_059, 속성: {'name': '우회도로', 'year': '2024'}
# 태그: ER44_A9990010_060, 속성: {'name': '접도구역', 'year': '2024'}
# 태그: ER45_A9990004_061, 속성: {'name': '도로점용(점)', 'year': '2024'}
# 태그: ER46_A9990005_062, 속성: {'name': '도로점용(선)', 'year': '2024'}
# 태그: ER47_A9990006_063, 속성: {'name': '도로점용(면)', 'year': '2024'}
# 태그: EC09_A0010000_064, 속성: {'name': '차도부경계', 'year': '2024'}
# 태그: ER49_A9990013_065, 속성: {'name': '측점', 'year': '2024'}
#
# 변경된 XML 내용이 'output.xml' 파일로 저장되었습니다.

# %% [markdown]
# ### Text 추출

# %%
import xml.etree.ElementTree as ET

tree = ET.parse(r'C:\sjbang\공간정보산업진흥원\code\output.xml')
root = tree.getroot()

for child in root:
    # print(child.tag, child.attrib)
    print(child.tag + ' / ' + child.attrib.get('name') + ' / ' + str(child.attrib.get('div')) + ' / ' + child.attrib.get('year'))
# Out:
# A1_NODE_001 / 주행경로노드 / None / 2025
# A2_LINK_002 / 주행경로링크 / ngii / 2025
# A3_DRIVEWAYSECTION_003 / 차도구간(교량) / ngii / 2024
# A3_DRIVEWAYSECTION_004 / 차도구간(터널) / ngii / 2024
# A3_DRIVEWAYSECTION_005 / 차도구간(지하차도) / ngii / 2024
# A3_DRIVEWAYSECTION_006 / 차도구간(고가차도) / ngii / 2024
# A3_DRIVEWAYSECTION_007 / 차도구간(IC) / ngii / 2024
# A3_DRIVEWAYSECTION_008 / 차도구간(JC) / ngii / 2025
# A4_SUBSIDIARYSECTION_009 / 부속구간(휴게소) / ngii / 2025
# A4_SUBSIDIARYSECTION_010 / 부속구간(졸음쉼터) / ngii / 2024
# A4_SUBSIDIARYSECTION_011 / 부속구간(버스정류장) / ngii / 2024
# A4_SUBSIDIARYSECTION_012 / 부속구간(비상정차대) / ngii / 2024
# A4_SUBSIDIARYSECTION_013 / 부속구간(POP) / ngii / 2025
# A4_SUBSIDIARYSECTION_014 / 부속구간(긴급제동시설) / ngii / 2024
# A5_PARKINGLOT_015 / 주차면 / ngii / 2025
# AE_SLOPE_016 / 종단경사 / ex / 2024
# B1_SAFETYSIGN_017 / 교통안전표지 / None / 2024
# B2_SURFACELINEMARK_018 / 노면선표시 / None / 2025
# B3_SURFACEMARK_019 / 노면안내표시 / None / 2025
# BE_ROADSIGN_020 / 도로안내표지 / None / 2024
# BE_VMS_021 / 도로전광표지(VMS) / None / 2024
# C2_KILOPOST_022 / 이정(거리표) / None / 2024
# C2_KILOPOST_023 / 이정(갓길이정) / None / 2025
# C3_VEHICLEPROTECTIONSAFETY_024 / 차량방호안전시설(중앙분리대) / None / 2024
# C3_VEHICLEPROTECTIONSAFETY_025 / 차량방호안전시설(방호울타리) / None / 2024
# C3_VEHICLEPROTECTIONSAFETY_026 / 차량방호안전시설(충격흡수시설) / None / 2024
# C4_SPEEDBUMP_027 / 과속방지턱 / None / 2024
# C5_HEIGHTBARRIER_028 / 높이장애물 / None / 2025
# C5_HEIGHTBARRIER_029 / 차로신호제어기(LCS) / None / 2024
# DE_FACILDOT_030 / 제설시설 / None / 2024
# DE_INCLINE_031 / 사면(도로절개면) / None / 2024
# DE_INCLINE_032 / 사면(도로성토면) / None / 2024
# DE_FENCE_033 / 벽/울타리(석축) / None / 2024
# DE_FENCE_034 / 벽/울타리(낙석방지시설) / None / 2024
# DE_FENCE_035 / 벽/울타리(방음시설) / None / 2024
# DE_FENCE_036 / 벽/울타리(옹벽) / None / 2024
# DE_CCTV_037 / CCTV / None / 2025
# DE_LIGHT_038 / 가로등 / None / 2024
# DE_TOLLGATE_039 / 요금소 / None / 2024
# DE_VDS_040 / 차량검지기(VDS) / None / 2025
# DE_CULVERT_041 / 통로박스 / None / 2024
# DE_ROAD_042 / 단위 도로면 / None / 2025
# DE_ROADPAVEMENT_043 / 단위 포장면 / None / 2025
# DE_DSRC_044 / DSRC / None / 2025
# DE_SOS_045 / 긴급전화 / None / 2025
# EC01_A0020000_046 / 도로대장 총괄 / None / 2024
# ER16_A9990001_047 / 도로중심선교점 / None / 2024
# EC08_A0080000_048 / 교차시설 / None / 2024
# ER17_A9990002_049 / 오르막차로 / None / 2024
# ER20_C0076117_050 / 측구 / None / 2024
# ER21_C9070001_051 / 배수암거/배수관 / None / 2024
# ER30_C9070001_052 / 가로수 / None / 2024
# ER31_C0246120_053 / 지하매설물 / None / 2024
# ER32_C0246341_054 / 공동구 / None / 2024
# ER36_C9530009_055 / 생태통로 / None / 2024
# ER40_A999011_056 / 실연장 / None / 2024
# ER41_A9990007_057 / 도로구역 / None / 2024
# ER42_A9990008_058 / 유료도로 / None / 2024
# ER43_A9990009_059 / 우회도로 / None / 2024
# ER44_A9990010_060 / 접도구역 / None / 2024
# ER45_A9990004_061 / 도로점용(점) / None / 2024
# ER46_A9990005_062 / 도로점용(선) / None / 2024
# ER47_A9990006_063 / 도로점용(면) / None / 2024
# EC09_A0010000_064 / 차도부경계 / None / 2024
# ER49_A9990013_065 / 측점 / None / 2024
